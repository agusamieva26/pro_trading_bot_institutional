# %% [markdown]
# # Walk-Forward Template
# Usa este cuaderno para experimentar con ventanas de entrenamiento/prueba, métricas y sensibilidad.

# %%
import pandas as pd, numpy as np
print('Ready for research 🚀')
